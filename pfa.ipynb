# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns 

x1 = pd.ExcelFile("class0.xlsx")
x2 = pd.ExcelFile("class1.xlsx")

# %%
print(x1.sheet_names)
# Out:
# ['Sheet1']

# %%
print(x2.sheet_names)
# Out:
# ['Sheet1']

# %%
df1 = x1.parse('Sheet1')
df2 = x2.parse('Sheet1')

# %%
df1.head()
# Out:
#    Unnamed: 0  Accuracy  Anderson_Darling_dist      CVM_dist       DTS_dist  \
# 0           0  0.655679             142.358926  17305.426315  221344.041952
# 1           1  0.658317             149.326050  17991.936448  233321.575170
# 2           2  0.636603             151.834834  17858.327633  301797.391653
# 3           3  0.628331             157.596448  18496.944669  338601.232668
# 4           4  0.665276             143.154374  17434.462144  208002.026768
#
#    Kolmogorov_Smirnov_dist  Kuiper_dist  Wasserstein_dist
# 0                 0.403032     0.209101      1.372197e+07
# 1                 0.407537     0.216773      1.449220e+07
# 2                 0.420872     0.283529      1.852594e+07
# 3                 0.447516     0.294027      2.086102e+07
# 4                 0.395216     0.210795      1.285641e+07

# %%
df2.head()
# Out:
#    Unnamed: 0  Accuracy  Anderson_Darling_dist      CVM_dist      DTS_dist  \
# 0           0  0.655679              99.048638  15634.885010  22641.483978
# 1           1  0.658317              99.821544  15789.793038  17223.684906
# 2           2  0.636603             104.880104  16834.204296  18221.589016
# 3           3  0.628331             105.842270  17014.019759  20955.350701
# 4           4  0.665276              98.143218  15473.745320  17348.619010
#
#    Kolmogorov_Smirnov_dist  Kuiper_dist  Wasserstein_dist
# 0                 0.268510     0.073295     509003.018679
# 1                 0.269432     0.073527     386236.819153
# 2                 0.282402     0.073018     445128.353267
# 3                 0.284815     0.075172     509501.517399
# 4                 0.265537     0.070503     384517.318427

# %%
#df1.shape
df2.shape
# Out:
# (100, 8)

# %%
df3 = pd.read_csv("Friday-WorkingHours-Afternoon-DDos.pcap_ISCX.csv")

# %%
df3.sample(10)
# Out:
#          Destination Port   Flow Duration   Total Fwd Packets  \
# 187463                 80         3052076                   4
# 203560                 53           61639                   2
# 214450              10425               3                   2
# 181553                 80         6184859                   5
# 183045                 80         5192829                   6
# 14934                 443              91                   2
# 10174               55707              47                   2
# 195494              42389         6502642                   1
# 75677                  80           94695                   3
# 94025                  80        82232681                   9
#
#          Total Backward Packets  Total Length of Fwd Packets  \
# 187463                        0                           24
# 203560                        2                           68
# 214450                        0                           37
# ...

# %%
df3.shape
# Out:
# (225745, 79)

# %%
print(df3.columns)
# Out:
# Index([' Destination Port', ' Flow Duration', ' Total Fwd Packets',
#        ' Total Backward Packets', 'Total Length of Fwd Packets',
#        ' Total Length of Bwd Packets', ' Fwd Packet Length Max',
#        ' Fwd Packet Length Min', ' Fwd Packet Length Mean',
#        ' Fwd Packet Length Std', 'Bwd Packet Length Max',
#        ' Bwd Packet Length Min', ' Bwd Packet Length Mean',
#        ' Bwd Packet Length Std', 'Flow Bytes/s', ' Flow Packets/s',
#        ' Flow IAT Mean', ' Flow IAT Std', ' Flow IAT Max', ' Flow IAT Min',
#        'Fwd IAT Total', ' Fwd IAT Mean', ' Fwd IAT Std', ' Fwd IAT Max',
#        ' Fwd IAT Min', 'Bwd IAT Total', ' Bwd IAT Mean', ' Bwd IAT Std',
#        ' Bwd IAT Max', ' Bwd IAT Min', 'Fwd PSH Flags', ' Bwd PSH Flags',
#        ' Fwd URG Flags', ' Bwd URG Flags', ' Fwd Header Length',
#        ' Bwd Header Length', 'Fwd Packets/s', ' Bwd Packets/s',
#        ' Min Packet Length', ' Max Packet Length', ' Packet Length Mean',
# ...

# %%
df4 = pd.read_csv("Friday-WorkingHours-Afternoon-PortScan.pcap_ISCX.csv")

# %%
df4.head()
# Out:
#     Destination Port   Flow Duration   Total Fwd Packets  \
# 0                 22         1266342                  41
# 1                 22         1319353                  41
# 2                 22             160                   1
# 3                 22         1303488                  41
# 4              35396              77                   1
#
#     Total Backward Packets  Total Length of Fwd Packets  \
# 0                       44                         2664
# 1                       44                         2664
# 2                        1                            0
# 3                       42                         2728
# 4                        2                            0
#
#     Total Length of Bwd Packets   Fwd Packet Length Max  \
# 0                          6954                     456
# 1                          6954                     456
# 2                             0                       0
# ...

# %%
df4.shape
# Out:
# (286467, 79)

# %%
df5 = pd.read_csv("Friday-WorkingHours-Morning.pcap_ISCX.csv")

# %%
df5.sample(10)
# Out:
#          Destination Port   Flow Duration   Total Fwd Packets  \
# 176042                 53             233                   2
# 73796                  53           48368                   1
# 13802                  80       116131381                  16
# 11180                  53           88643                   1
# 102482                 53           59290                   2
# 173157                 53           24373                   2
# 159104                 80          509083                   4
# 159462                 80       115710586                  16
# 142772              43916              21                   1
# 11528               49827              37                   1
#
#          Total Backward Packets  Total Length of Fwd Packets  \
# 176042                        2                           68
# 73796                         1                           76
# 13802                        14                          517
# ...

# %%
df5.shape
# Out:
# (191033, 79)

# %%
if df3.columns.all() == df4.columns.all() and df3.columns.all() == df5.columns.all():
    print("1")
# Out:
# 1

# %%
df3.columns = df3.columns.str.strip().str.lower().str.replace(' ', '_').str.replace('(', '').str.replace(')', '')
df3.head()
# Out:
#    destination_port  flow_duration  total_fwd_packets  total_backward_packets  \
# 0             54865              3                  2                       0
# 1             55054            109                  1                       1
# 2             55055             52                  1                       1
# 3             46236             34                  1                       1
# 4             54863              3                  2                       0
#
#    total_length_of_fwd_packets  total_length_of_bwd_packets  \
# 0                           12                            0
# 1                            6                            6
# 2                            6                            6
# 3                            6                            6
# 4                           12                            0
#
#    fwd_packet_length_max  fwd_packet_length_min  fwd_packet_length_mean  \
# ...

# %%
df3.label.value_counts(normalize=True)
# Out:
# DDoS      0.567131
# BENIGN    0.432869
# Name: label, dtype: float64

# %%
df3.label.value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
df4.columns = df4.columns.str.strip().str.lower().str.replace(' ', '_').str.replace('(', '').str.replace(')', '')
df4.head()
# Out:
#    destination_port  flow_duration  total_fwd_packets  total_backward_packets  \
# 0                22        1266342                 41                      44
# 1                22        1319353                 41                      44
# 2                22            160                  1                       1
# 3                22        1303488                 41                      42
# 4             35396             77                  1                       2
#
#    total_length_of_fwd_packets  total_length_of_bwd_packets  \
# 0                         2664                         6954
# 1                         2664                         6954
# 2                            0                            0
# 3                         2728                         6634
# 4                            0                            0
#
#    fwd_packet_length_max  fwd_packet_length_min  fwd_packet_length_mean  \
# ...

# %%
df4.label.value_counts()
# Out:
# PortScan    158930
# BENIGN      127537
# Name: label, dtype: int64
